# %% [markdown]
# # <center>Индивидуальное задание 7</center>
# ## <center>Задача 2</center>

# %%
import numpy as np
import pandas as pd


# устанавливаем точность чисел с плавающей точкой
# %precision %.2f
# Out:
# '%.2f'

# %% [markdown]
# В прилагаемом файле представлены данные, собранные путем голосования за самые лучшие (или, по крайней мере, самые популярные) **конфеты Хэллоуина**.
#
# Обучите модель **линейной многомерной регрессии**.
#
# В качестве **предикторов** выступают поля: chocolate, fruity, caramel, peanutyalmondy, nougat, crispedricewafer, hard, bar, pluribus, sugarpercent, pricepercent, **отклик** — winpercent.
#
# В качестве тренировочного набора данных используйте данные из файла, **за иключением следующих конфет**: Caramel Apple Pops, Nestle Crunch. Обучите модель.

# %%
df = pd.read_csv('https://courses.openedu.ru/assets/courseware/v1/a11f0b9cb0074fdacc112eee71eb0b67/asset-v1:ITMOUniversity+BIGDATAINTROML+fall_2022_ITMO+type@asset+block/candy-data.csv')
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent  Y
# 0   66.971725  1
# 1   67.602936  1
# 2   32.261086  0
# 3   46.116505  0
# 4   52.341465  1

# %%
df.shape
# Out:
# (70, 14)

# %%
df_test = df[(df.competitorname == 'Caramel Apple Pops') | (df.competitorname == 'Nestle Crunch')]
X_test = df_test.drop(columns=['competitorname', 'winpercent', 'Y'])
y_test = df_test.winpercent
df_test.head()
# Out:
#         competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 9   Caramel Apple Pops          0       1        1               0       0
# 43       Nestle Crunch          1       0        0               0       0
#
#     crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 9                  0     0    0         0         0.604         0.325
# 43                 1     0    1         0         0.313         0.767
#
#     winpercent  Y
# 9    34.517681  0
# 43   66.470680  1

# %%
df_train = df[(df.competitorname != 'Caramel Apple Pops') & (df.competitorname != 'Nestle Crunch')]
X_train = df_train.drop(columns=['competitorname', 'winpercent', 'Y'])
y_train = df_train.winpercent
df_train.shape
# Out:
# (68, 14)

# %%
from sklearn.linear_model import LinearRegression

reg_model = LinearRegression().fit(X_train, y_train)

y_test_pred = reg_model.predict(X_test)
np.round(y_test_pred, 3)
# Out:
# array([54.291, 61.068])

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_test_pred)
# Out:
# 0.17692275104590882

# %%
y_test_1_pred = reg_model.predict([[0,1,1,0,0,1,0,0,0,0.162, 0.71]])
np.round(y_test_1_pred, 3)
# Out:
# array([53.873])
