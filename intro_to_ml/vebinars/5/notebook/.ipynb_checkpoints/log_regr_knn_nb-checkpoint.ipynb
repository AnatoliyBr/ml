# %% [markdown]
# # <center>Data Scientist. Задача классификации. KNN, Логистическая регрессия, NB</center>
# ## <center>Часть 1. Разведочный анализ данных – Exploratory Data Analysis (EDA)</center>

# %% [markdown]
# Рассмотрим датасет пассажиров "Титаника", который можно скачать [тут](https://www.kaggle.com/competitions/titanic/data).
#
# Описание датасета:
# - **PassengerId** ––– id пассажира, можно взять за индекс
# - **Survived** (целевой признак) ––– выжил ли пассажир (0 = Нет, 1 = Да);
# - **Pclass** ––– класс билета (1 = 1st, 2 = 2nd, 3 = 3rd);
# - **Sex** ––– пол (female или male)
# - **Age** ––– возраст в годах
# - **SibSp** –––	количество братьев, сестёр (в том числе сводных) и супругов на борту
# - **Parch**	–––	количество детей и родителей на борту
# - **Ticket** ––– номер билета
# - **Fare** ––– стоимость проезда пассажира
# - **Cabin** ––– номер каюты
# - **Embarked** ––– порт посадки пассажира (C = Cherbourg, Q = Queenstown, S = Southampton).
#
# Необходимо решить задачу классификации и научиться предсказывать целовой признак **Survived** выживет ли пассажир по его нецелевым признакам.

# %% [markdown]
# Сперва подключим необходимые библиотеки.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# устанавливаем точность чисел с плавающей точкой
# %precision %.4f

import warnings
warnings.filterwarnings('ignore')  # отключаем предупреждения

# %% [markdown]
# Считываем обучающую выборку.

# %%
df = pd.read_csv('../data/titanic/titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Проверяем общее количество пропущенных значений.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Признаки **Age, Cabin** и **Embarked** имеют пропущенные значения, особенно признак **Cabin**. Будем это учитывать в дальнейшем при очистке данных.

# %% [markdown]
# Также сразу появляется интерес посмотреть на статистику по целевому признаку. А именно, сколько каких значений он принимает. Для этого воспользуемся функцией <code>value_counts()</code>.

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# Анализ данных, особенно достаточно сложный, легче воспринимается визуально. Поэтому часто будем прибегать к средствам визуализации. Например, удобно использовать функцию <code>countplot()</code> библиотеки seaborn.

# %%
sns.countplot('Survived', data=df);  # можно не писать plt.show(), а точка с запятой убирает лишнюю информацию

# %% [markdown]
# Ну и конечно посмотрим каков был шанс выжить судя по данным из тестовой выборки.

# %%
df['Survived'].mean()
# Out:
# 0.3838

# %% [markdown]
# Из пассажиров обучающей выборки чуть больше **38%** смогли уцелеть. Далее проведём первичный анализ признаков по отдельности и попарно. Особенно интересуют зависимости целевого признака от нецелевых.

# %% [markdown]
# ## Первичный анализ признаков

# %% [markdown]
# ### Категориальный признак Sex

# %%
df.groupby(['Sex', 'Survived'])['Survived'].count()  # оба признака категориальные, группируем и считаем колличество
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sns.barplot(x = "Sex", y = "Survived", data = df);

# %% [markdown]
# Выжило около **75%** женщин и всего около **20%** мужчин.

# %%
sns.countplot('Sex',hue='Survived',data=df);

# %% [markdown]
# Несмотря на то, что больншинство пассажиров были мужчинами, выжило намного больше женщин. Признак **Sex** кажется очень важным для этой задачи и имеющим сильную зависимость с целевым признаком. Проанализируем другие признаки.

# %% [markdown]
# ## Порядковый признак Pclass

# %%
pd.crosstab(df['Pclass'], df['Survived'], margins=True).style.background_gradient()
# Out:
# <style type="text/css">
# #T_02429_row0_col0, #T_02429_row1_col1, #T_02429_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_02429_row0_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_02429_row0_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_02429_row1_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_02429_row2_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_02429_row2_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_02429_row2_col2 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_02429_row3_col0, #T_02429_row3_col1, #T_02429_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_02429">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_02429_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_02429_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_02429_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02429_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_02429_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_02429_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_02429_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_02429_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_02429_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_02429_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_02429_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_02429_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_02429_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_02429_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_02429_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_02429_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_02429_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_02429_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_02429_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot(x = "Pclass", y = "Survived", data = df);

# %%
sns.countplot('Pclass', hue='Survived', data=df);

# %% [markdown]
# Несмотря на подавляющее большинство пассажиров третьего класса, в основном выжили пассажиры из классов повыше. Видимо пассажиры из первого класса были в приоритете при эвакуации/спасении. Признак **Pclass** возможно тоже важен для предсказания выживания.
#
# Посмотрим на комбинацию рассмотренных признаков **Sex** и **Pclass** и связь с целевым признаком.

# %%
pd.crosstab([df['Sex'], df['Survived']], df['Pclass'], margins=True).style.background_gradient()
# Out:
# <style type="text/css">
# #T_9e81e_row0_col0, #T_9e81e_row0_col1, #T_9e81e_row0_col3, #T_9e81e_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9e81e_row0_col2, #T_9e81e_row1_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_9e81e_row1_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_9e81e_row1_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_9e81e_row1_col3 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_9e81e_row2_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_9e81e_row2_col1, #T_9e81e_row2_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_9e81e_row2_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_9e81e_row3_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_9e81e_row3_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_9e81e_row3_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_9e81e_row4_col0, #T_9e81e_row4_col1, #T_9e81e_row4_col2, #T_9e81e_row4_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e81e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_9e81e_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_9e81e_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_9e81e_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_9e81e_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e81e_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_9e81e_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_9e81e_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_9e81e_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_9e81e_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_9e81e_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_9e81e_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_9e81e_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_9e81e_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_9e81e_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_9e81e_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_9e81e_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_9e81e_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_9e81e_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_9e81e_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_9e81e_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_9e81e_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_9e81e_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_9e81e_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_9e81e_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_9e81e_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_9e81e_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_9e81e_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_9e81e_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_9e81e_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_9e81e_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_9e81e_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_9e81e_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df);

# %% [markdown]
# Женщины из 1го класса спаслись почти полностью (более **95%** из них выжили). Только 3 женщины из 94 в 1ом классе погибли. Видимо спасали в первую очередь женщин из первого класса, мужчины же, даже из первого класса, имеют низкий процент выживших.
#
# В целом, отметим возмужную важность признака **Pclass**.

# %% [markdown]
# ## Количественный признак Age

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
_, ax = plt.subplots(1, 2, figsize=(15, 5))
sns.violinplot("Pclass", "Age", hue="Survived", data=df, split=True, ax=ax[0])
ax[0].set_title('Pclass vs Age')
ax[0].set_yticks(range(0, 100, 10))
sns.violinplot("Sex", "Age", hue="Survived", data=df, split=True, ax=ax[1])
ax[1].set_title('Sex vs Age')
ax[1].set_yticks(range(0, 100, 10))
plt.show()

# %% [markdown]
# - Независимо от класса, маленькие дети имеют хорошую долю выживших
# - У мужчин доля выживших меньше, особенно у пожилых

# %% [markdown]
# Мы отмечали, что признак **Age** имеет 177 пропущенных значений. Данных очень мало, поэтому попытаемся не выкидывать эти наблюдения, а заполнить пропущенные значения чем то осмысленным.
#
# Заменить пропущенные возраста просто на средний возраст пассажиров будет не очень хорошим решением.
#
# Не поверите, но определить возраст точнее поможет имя, признак **Name**. Как? Этот признак содержит обращения Mr., Mrs., Dr. и т.д.

# %%
df['Mr_Mrs'] = 0
for i in df:
    df['Mr_Mrs']=df['Name'].str.extract('([A-Za-z]+)\.') #lets extract the Salutations
pd.crosstab(df['Sex'],df['Mr_Mrs']).style.background_gradient()
# Out:
# <style type="text/css">
# #T_56a45_row0_col0, #T_56a45_row0_col1, #T_56a45_row0_col3, #T_56a45_row0_col4, #T_56a45_row0_col5, #T_56a45_row0_col7, #T_56a45_row0_col8, #T_56a45_row0_col12, #T_56a45_row0_col15, #T_56a45_row0_col16, #T_56a45_row1_col2, #T_56a45_row1_col6, #T_56a45_row1_col9, #T_56a45_row1_col10, #T_56a45_row1_col11, #T_56a45_row1_col13, #T_56a45_row1_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_56a45_row0_col2, #T_56a45_row0_col6, #T_56a45_row0_col9, #T_56a45_row0_col10, #T_56a45_row0_col11, #T_56a45_row0_col13, #T_56a45_row0_col14, #T_56a45_row1_col0, #T_56a45_row1_col1, #T_56a45_row1_col3, #T_56a45_row1_col4, #T_56a45_row1_col5, #T_56a45_row1_col7, #T_56a45_row1_col8, #T_56a45_row1_col12, #T_56a45_row1_col15, #T_56a45_row1_col16 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_56a45">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Mr_Mrs</th>
#       <th id="T_56a45_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_56a45_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_56a45_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_56a45_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_56a45_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_56a45_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_56a45_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_56a45_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_56a45_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_56a45_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_56a45_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_56a45_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_56a45_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_56a45_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_56a45_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_56a45_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_56a45_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56a45_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_56a45_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_56a45_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_56a45_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_56a45_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_56a45_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_56a45_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_56a45_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_56a45_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_56a45_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_56a45_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_56a45_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_56a45_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_56a45_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_56a45_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_56a45_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_56a45_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_56a45_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56a45_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_56a45_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_56a45_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_56a45_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_56a45_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_56a45_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_56a45_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_56a45_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_56a45_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_56a45_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_56a45_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_56a45_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_56a45_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_56a45_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_56a45_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_56a45_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_56a45_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_56a45_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Упростим и объединим некоторые обращения.

# %%
df['Mr_Mrs'].\
replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],\
        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'], inplace=True)
pd.crosstab(df['Sex'],df['Mr_Mrs']).style.background_gradient()
# Out:
# <style type="text/css">
# #T_905ea_row0_col0, #T_905ea_row0_col2, #T_905ea_row0_col4, #T_905ea_row1_col1, #T_905ea_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_905ea_row0_col1, #T_905ea_row0_col3, #T_905ea_row1_col0, #T_905ea_row1_col2, #T_905ea_row1_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_905ea">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Mr_Mrs</th>
#       <th id="T_905ea_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_905ea_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_905ea_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_905ea_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_905ea_level0_col4" class="col_heading level0 col4" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_905ea_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_905ea_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_905ea_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_905ea_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_905ea_row0_col3" class="data row0 col3" >127</td>
#       <td id="T_905ea_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_905ea_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_905ea_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_905ea_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_905ea_row1_col2" class="data row1 col2" >528</td>
#       <td id="T_905ea_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_905ea_row1_col4" class="data row1 col4" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.loc[(df['Mr_Mrs'] == 'Mr') & (df['Sex'] == 'female'), "Mr_Mrs"] = 'Mrs' # исправляем обращение к доктору женщине
pd.crosstab(df['Sex'],df['Mr_Mrs']).style.background_gradient()
# Out:
# <style type="text/css">
# #T_c6d86_row0_col0, #T_c6d86_row0_col2, #T_c6d86_row0_col4, #T_c6d86_row1_col1, #T_c6d86_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c6d86_row0_col1, #T_c6d86_row0_col3, #T_c6d86_row1_col0, #T_c6d86_row1_col2, #T_c6d86_row1_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6d86">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Mr_Mrs</th>
#       <th id="T_c6d86_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_c6d86_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_c6d86_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_c6d86_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_c6d86_level0_col4" class="col_heading level0 col4" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6d86_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_c6d86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c6d86_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_c6d86_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c6d86_row0_col3" class="data row0 col3" >128</td>
#       <td id="T_c6d86_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c6d86_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_c6d86_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_c6d86_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c6d86_row1_col2" class="data row1 col2" >528</td>
#       <td id="T_c6d86_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_c6d86_row1_col4" class="data row1 col4" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.groupby('Mr_Mrs')['Age'].mean()  # теперь более точно сможем задать средние возраста по группам пассажиров
# Out:
# Mr_Mrs
# Master     4.574167
# Miss      21.860000
# Mr        32.699755
# Mrs       36.099099
# Other     45.888889
# Name: Age, dtype: float64

# %%
df.loc[(df['Age'].isnull()) & (df['Mr_Mrs'] == 'Master'), 'Age'] = 5
df.loc[(df['Age'].isnull()) & (df['Mr_Mrs'] == 'Miss'), 'Age'] = 22
df.loc[(df['Age'].isnull()) & (df['Mr_Mrs'] == 'Mr'), 'Age'] = 33
df.loc[(df['Age'].isnull()) & (df['Mr_Mrs'] == 'Mrs'), 'Age'] = 36
df.loc[(df['Age'].isnull()) & (df['Mr_Mrs'] == 'Other'), 'Age'] = 46
df['Age'].isnull().any()  # избавились от пропусков в данных о возрасте
# Out:
# False

# %%
_, ax = plt.subplots(1, 2, figsize=(20, 10))
df[df['Survived'] == 0]['Age'].plot.hist(ax=ax[0], edgecolor='black', color='red', bins=15)
ax[0].set_title('Survived == 0')
x1 = list(range(0, 100, 5))
ax[0].set_xticks(x1)
df[df['Survived'] == 1].Age.plot.hist(ax=ax[1],color='blue',edgecolor='black', bins=15)
ax[1].set_title('Survived == 1')
x2 = list(range(0, 100, 5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# - Не только женщин, но и самых маленьких детей спасили в первую очередь
#
# - Самый пожилой 80-летний пассажир также был спасён
#
# - Больше всего погибло молодых людей около 30 лет

# %%
sns.factorplot('Pclass', 'Survived', col='Mr_Mrs', data=df);

# %% [markdown]
# Независимо от класса пассажиров, в первую очередь спасали женщин и детей.

# %% [markdown]
# ## Категориальный признак Embarked

# %%
pd.crosstab([df['Embarked'], df['Pclass']], [df['Sex'], df['Survived']], margins=True).\
        style.background_gradient()
# Out:
# <style type="text/css">
# #T_c75db_row0_col0, #T_c75db_row1_col2, #T_c75db_row1_col3, #T_c75db_row1_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c75db_row0_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_c75db_row0_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c75db_row0_col3 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_c75db_row0_col4, #T_c75db_row2_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c75db_row1_col0, #T_c75db_row3_col0, #T_c75db_row3_col1, #T_c75db_row3_col2, #T_c75db_row3_col3, #T_c75db_row3_col4, #T_c75db_row4_col0, #T_c75db_row4_col2, #T_c75db_row4_col3, #T_c75db_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c75db_row1_col1, #T_c75db_row6_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c75db_row2_col0, #T_c75db_row5_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c75db_row2_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_c75db_row2_col2 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_c75db_row2_col4, #T_c75db_row7_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_c75db_row4_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c75db_row5_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_c75db_row5_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_c75db_row5_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c75db_row5_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_c75db_row6_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_c75db_row6_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_c75db_row6_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_c75db_row6_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c75db_row7_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_c75db_row7_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_c75db_row7_col3, #T_c75db_row8_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_c75db_row7_col4 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_c75db_row8_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_c75db_row8_col2 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_c75db_row8_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_c75db_row8_col4 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_c75db_row9_col0, #T_c75db_row9_col1, #T_c75db_row9_col2, #T_c75db_row9_col3, #T_c75db_row9_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c75db">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_c75db_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_c75db_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_c75db_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_c75db_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_c75db_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_c75db_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_c75db_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_c75db_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c75db_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_c75db_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_c75db_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c75db_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_c75db_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_c75db_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_c75db_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_c75db_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c75db_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_c75db_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_c75db_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_c75db_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_c75db_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_c75db_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_c75db_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_c75db_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_c75db_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_c75db_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_c75db_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c75db_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_c75db_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_c75db_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_c75db_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_c75db_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_c75db_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_c75db_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_c75db_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_c75db_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_c75db_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_c75db_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_c75db_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_c75db_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_c75db_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_c75db_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_c75db_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_c75db_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_c75db_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_c75db_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_c75db_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_c75db_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_c75db_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_c75db_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_c75db_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_c75db_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_c75db_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_c75db_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_c75db_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_c75db_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_c75db_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_c75db_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_c75db_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_c75db_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_c75db_row9_col1" class="data row9 col1" >2

# %%
sns.factorplot('Embarked', 'Survived', data=df);

# %% [markdown]
# Есть различия шанса выжить для пассажиров с разными портами посадки.

# %%
_, ax = plt.subplots(2, 2, figsize=(20,15))
sns.countplot('Embarked', data=df, ax=ax[0,0])
ax[0,0].set_title('Count of Embarked')
sns.countplot('Embarked', hue='Sex', data=df, ax=ax[0,1])
ax[0,1].set_title('Embarked vs Sex')
sns.countplot('Embarked', hue='Survived', data=df, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=df, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# - Самая большая посадка в порту S, преимущественно мужчин и в 3ий класс
# - Кажется что те, кто сел в порту C более удачливые, вероятно из-за соотношения богатых к бедным и женщин к мужчинам

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col='Embarked', data=df);

# %% [markdown]
# - Женщины из 1го и 2го класса почти все выжили, не важно где сели.
# - Для женщин наименьший шанс выжить, если они сели в порту S и они из 3го класса. Этот шанс сравним с шансом мужчин из 1го класса.
# - Самая печальная картина для мужчин, если они сели в порту Q, так как почти все они пассажиры 3го класса.

# %% [markdown]
# Также помним про нулевые значения признака **Embarked**.

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %% [markdown]
# Всего два значения пропущены. Так как в большинстве случаем пассажиры сели в порту S, то с чистой совестью заполняем эти значения этим портом.

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df['Embarked'].isnull().any()  # избавились от пропущенных значений признака Embarked
# Out:
# False

# %% [markdown]
# ## Дискретный признак SibSp
# - Sibling = сводные/родные братья/сестры
# - Spouse = муж/жена

# %%
pd.crosstab(df['SibSp'], df['Survived']).style.background_gradient()
# Out:
# <style type="text/css">
# #T_57601_row0_col0, #T_57601_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_57601_row1_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_57601_row1_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_57601_row2_col0, #T_57601_row4_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_57601_row2_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_57601_row3_col0, #T_57601_row3_col1, #T_57601_row4_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_57601_row5_col0, #T_57601_row5_col1, #T_57601_row6_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_57601_row6_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_57601">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_57601_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_57601_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57601_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57601_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_57601_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_57601_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57601_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_57601_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_57601_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57601_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_57601_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_57601_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57601_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_57601_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_57601_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57601_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_57601_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_57601_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_57601_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_57601_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_57601_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_57601_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_57601_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.barplot('SibSp', 'Survived', data=df);

# %%
pd.crosstab(df['SibSp'],df['Pclass']).style.background_gradient()
# Out:
# <style type="text/css">
# #T_c0c27_row0_col0, #T_c0c27_row0_col1, #T_c0c27_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c0c27_row1_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_c0c27_row1_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_c0c27_row1_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c0c27_row2_col0, #T_c0c27_row4_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_c0c27_row2_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_c0c27_row2_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c0c27_row3_col0, #T_c0c27_row3_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c0c27_row3_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c0c27_row4_col0, #T_c0c27_row4_col1, #T_c0c27_row5_col0, #T_c0c27_row5_col1, #T_c0c27_row5_col2, #T_c0c27_row6_col0, #T_c0c27_row6_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c0c27_row6_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_c0c27">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_c0c27_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_c0c27_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_c0c27_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0c27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0c27_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_c0c27_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_c0c27_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_c0c27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0c27_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_c0c27_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_c0c27_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_c0c27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0c27_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_c0c27_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_c0c27_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_c0c27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c0c27_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c0c27_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_c0c27_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c0c27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c0c27_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_c0c27_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c0c27_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_c0c27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c0c27_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c0c27_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c0c27_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c0c27_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_c0c27_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_c0c27_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c0c27_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Кажется, что с ростом количества родных на борту сильно уменьшается шанс выжить начиная с 3 человек. Если на борту 5 или более родственников, то такие пассажиры точно погибали. Вероятно из-за попыток спасти семью, а не себя.
# - Однако причной является признак Pclass. Последняя таблица показывает, что все большие семьи были из 3го класса.

# %% [markdown]
# ## Дискретный признак Parch

# %%
pd.crosstab(df.Parch, df.Pclass).style.background_gradient()
# Out:
# <style type="text/css">
# #T_c5838_row0_col0, #T_c5838_row0_col1, #T_c5838_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c5838_row1_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_c5838_row1_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_c5838_row1_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c5838_row2_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c5838_row2_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c5838_row2_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_c5838_row3_col0, #T_c5838_row4_col1, #T_c5838_row5_col0, #T_c5838_row5_col1, #T_c5838_row6_col0, #T_c5838_row6_col1, #T_c5838_row6_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c5838_row3_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c5838_row3_col2, #T_c5838_row4_col0, #T_c5838_row4_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c5838_row5_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# </style>
# <table id="T_c5838">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_c5838_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_c5838_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_c5838_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5838_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5838_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_c5838_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_c5838_row0_col2" class="data row0 col2" >381</td>
#     </tr>
#     <tr>
#       <th id="T_c5838_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5838_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_c5838_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_c5838_row1_col2" class="data row1 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_c5838_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5838_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_c5838_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_c5838_row2_col2" class="data row2 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_c5838_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5838_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c5838_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_c5838_row3_col2" class="data row3 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c5838_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5838_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_c5838_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c5838_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c5838_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c5838_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c5838_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c5838_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c5838_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c5838_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_c5838_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c5838_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Опять же, большие семьи почти полностью из 3го класса.

# %%
sns.barplot('Parch', 'Survived', data=df);

# %% [markdown]
# - Опять же, не большое количество родственников увеличивает шансы выжить
# - Однако начиная с 4 шансы сильно уменьшаются

# %% [markdown]
# ## Выводы:
# - **Sex:** Скорее выживут женщины.
# - **Pclass:** 1ый класс имеет хорошие шансы выжить (женщины почти 100%), женщины из 2го классов тоже. 3ий класс пострадал больше всех.
# - **Age:** Дети около 5-10 лет имели хороший шанс выжить. Пассажиры окол 30-35 лет часто погибали.
# - **Embarked:** Кажется, что пассажирам, севшим в порту C повезло больше.
# - **Parch+SibSp:** Наличие 1-3 таких родственников показало хороший шанс выживания. Лучше, чем быть одному или в составе большой семьи, которая почти всегда из 3го класса.

# %% [markdown]
# ## Корреляция признаков

# %%
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn')
fig = plt.gcf()
fig.set_size_inches(10, 5)
plt.show()

# %% [markdown]
# Слишком большой корреляции нету, которая позволила бы сразу убрать из рассмотрения некоторые признаки, несущие в себе в основном избыточную информацию.
# Разве что можно присмотреться к **Pclass vs Fare**, и **SibSp vs Parch**.
#
# Но таким образом мы сравнили только количественные признаки.
#
# Пока продолжим анализ со всеми признаками.

# %% [markdown]
# ## <center>Часть 2. Feature Engineering and Data Cleaning</center>
#
# Далеко не всегда все признаки в данных важны или представляются в нужном виде. Поэтому после некоторого анализа данных и признаков часто нужно добавлять новые признаки и удалять неважные. Новые признаки могут быть основаны на некоторых наблюдениях в результате анализа данных, могут явно вычислятся из других признаков.
#
# Например, мы добавили признак **Mr_Mrs**, который позволил нам дополнить пропущенные значения в возрасте.
#
# Посмотрим какие полезные признаки ещё сможем создать, а какие существующие сможем привести к более удобному виду для дальнейшего обучения.

# %% [markdown]
# ## Новый признак возрастные категории Age_category
#
# У категориальных признаков есть свои преимущества по сравнению с количественными. Например, по категориальным признакам можно группировать.
#
# Воспользуемся признаком **Age** и выделим во множестве его значений (от 0 до 80) категории (интервалы).

# %%
df['Age_category'] = 0  # заполняем сначала значения нового признака нулями
df.loc[df['Age'] <= 16, 'Age_category'] = 0  # далле разбиваем возраста на 5 категорий
df.loc[(df['Age'] > 16) & (df['Age'] <= 32), 'Age_category'] = 1
df.loc[(df['Age'] > 32) & (df['Age'] <= 48), 'Age_category'] = 2
df.loc[(df['Age'] > 48) & (df['Age'] <= 64), 'Age_category'] = 3
df.loc[df['Age'] > 64, 'Age_category'] = 4
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Mr_Mrs  Age_category
# 0      0         A/5 21171   7.2500   NaN        S     Mr             1
# 1      0          PC 17599  71.2833   C85        C    Mrs             2
# 2      0  STON/O2. 3101282   7.9250   NaN        S   Miss             1
# 3      0            113803  53.1000  C123        S    Mrs             2
# 4      0            373450   8.0500   NaN        S     Mr             2

# %% [markdown]
# Ещё раз взглянем на корреляцию признаков.

# %%
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn')
fig = plt.gcf()
fig.set_size_inches(10, 5)
plt.show()

# %%
df['Age_category'].value_counts().to_frame().style.background_gradient(cmap='summer')  # пассажиров в категориях
# Out:
# <style type="text/css">
# #T_24267_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_24267_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_24267_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_24267_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_24267_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_24267">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24267_level0_col0" class="col_heading level0 col0" >Age_category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24267_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_24267_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_24267_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_24267_row1_col0" class="data row1 col0" >325</td>
#     </tr>
#     <tr>
#       <th id="T_24267_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_24267_row2_col0" class="data row2 col0" >104</td>
#     </tr>
#     <tr>
#       <th id="T_24267_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_24267_row3_col0" class="data row3 col0" >69</td>
#     </tr>
#     <tr>
#       <th id="T_24267_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_24267_row4_col0" class="data row4 col0" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Age_category', 'Survived', data = df,col = 'Pclass')
plt.show()

# %% [markdown]
# Делаем вывод, что вероятность выжить снижалась с ростом возраста независимо от класса билета.

# %% [markdown]
# ## Новые признаки размеров семей Family_Size и Alone
# Такие признаки позволят нам разглядеть зависимости от размеров семей, которые спрятаны в **Parch** и **SibSp**.

# %%
df['Family_Size'] = 0
df['Family_Size'] = df['Parch'] + df['SibSp']  # размер семьи
df['Alone'] = 0
df.loc[df['Family_Size'] == 0, 'Alone'] = 1  # путешествовал ли пассажир один

# %%
sns.factorplot('Family_Size', 'Survived', data=df);

# %%
sns.factorplot(x='Alone', y='Survived', data=df);

# %% [markdown]
# Шансы вижить существенно меньше для тех, кто был один или с семьей размера от 4

# %%
sns.factorplot('Alone', 'Survived', data=df, hue='Sex', col='Pclass');

# %% [markdown]
# Быть одному - плохо, неззависимо от пола или класса билета. Кроме женщин в 3ем классе, где просто было больше женщин, путешествующих одних.
#
# ## Новый признак категорий стоимости билета Fare
#
# Разобъём область значений на интервалы.

# %%
df['Fare_category'] = pd.qcut(df['Fare'], 5)
df.groupby(['Fare_category'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_be8d0_row0_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_be8d0_row1_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_be8d0_row2_col0 {
#   background-color: #7ebe66;
#   color: #000000;
# }
# #T_be8d0_row3_col0 {
#   background-color: #72b866;
#   color: #f1f1f1;
# }
# #T_be8d0_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_be8d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be8d0_level0_col0" class="col_heading level0 col0" >Survived</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fare_category</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be8d0_level0_row0" class="row_heading level0 row0" >(-0.001, 7.854]</th>
#       <td id="T_be8d0_row0_col0" class="data row0 col0" >0.217877</td>
#     </tr>
#     <tr>
#       <th id="T_be8d0_level0_row1" class="row_heading level0 row1" >(7.854, 10.5]</th>
#       <td id="T_be8d0_row1_col0" class="data row1 col0" >0.201087</td>
#     </tr>
#     <tr>
#       <th id="T_be8d0_level0_row2" class="row_heading level0 row2" >(10.5, 21.679]</th>
#       <td id="T_be8d0_row2_col0" class="data row2 col0" >0.424419</td>
#     </tr>
#     <tr>
#       <th id="T_be8d0_level0_row3" class="row_heading level0 row3" >(21.679, 39.688]</th>
#       <td id="T_be8d0_row3_col0" class="data row3 col0" >0.444444</td>
#     </tr>
#     <tr>
#       <th id="T_be8d0_level0_row4" class="row_heading level0 row4" >(39.688, 512.329]</th>
#       <td id="T_be8d0_row4_col0" class="data row4 col0" >0.642045</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Шансы выжить повышаются с ростом стоимости билета. Тут конечно и связь с классом билета.

# %%
df['Fare_category'] = 0
df.loc[df['Fare'] <= 7.91, 'Fare_category'] = 0
df.loc[(df['Fare'] > 7.91) & (df['Fare'] <= 14.454), 'Fare_category'] = 1
df.loc[(df['Fare'] > 14.454) & (df['Fare'] <= 31), 'Fare_category'] = 2
df.loc[(df['Fare'] > 31) & (df['Fare'] <= 513), 'Fare_category'] = 3

# %%
sns.factorplot('Fare_category', 'Survived', data=df, hue='Sex');

# %% [markdown]
# Этот признак может быть полезен в дальнейшем процессе обучения.
#
# ## Трансформация строк в числа
#
# Подготавливаем данные, приводим к удобному для обучению формату.

# %%
df['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
df['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)
df['Mr_Mrs'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], [0, 1, 2, 3, 4], inplace=True)

# %% [markdown]
# ## Удаление ненужных признаков
#
# **Name** –– неважно, категории обращений мистер и тд уже сделали.
#
# **Age** –– вместо него будем использовать категории возрастов **Age_category**.
#
# **Ticket** –– неважно.
#
# **SibSp** и **Parch** –– вместо них **Family_Size** и **Alone**
#
# **Fare** –– вместо него **Fare_category**.
#
# **Cabin** –– много пропущенных значений, есть повторяющиеся, не понятно что делать с этим признаком.
#
# **PassengerId** –– просто индекс.

# %%
df.drop(['Name', 'Age', 'Ticket', 'SibSp', 'Parch', 'Fare', 'Cabin', 'PassengerId'], axis=1, inplace=True)
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# Тут можно исследовать полученные положительные и отрицательные корреляции между признаками. Далее уже необходимо выбирать семейства моделей машинного обучения для решения задачи классификации.

# %% [markdown]
# ## <center>Часть 3. Логистическая регрессия - Logistic Regression</center>

# %% [markdown]
# ### Входные данные
# <br>
# <img src="https://www.tutorialspoint.com/machine_learning_with_python/images/star.jpg" width="500px"/>

# %% [markdown]
# ### Разделяющая гиперплоскость
# <br>
# <img src="https://www.tutorialspoint.com/machine_learning_with_python/images/red_line.jpg" width="500px"/>

# %% [markdown]
# ### Сигмоидная функция для оценки вероятности принадлежности к классу 1
# <br>
# <img src="https://qph.fs.quoracdn.net/main-qimg-05edc1873d0103e36064862a45566dba" width="500px"/>

# %% [markdown]
# Сделаем простое разделение train/test с использованием train_test_split(). А также масштабируем данные.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

cols = ["Pclass","Sex","Embarked","Mr_Mrs","Age_category","Family_Size","Alone","Fare_category"] 
X = df[cols]
y = df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

scaler = StandardScaler()  # воспользуемся стандартным трансформером

# масштабируем обучающую выборку и запоминаем среднее, стандартное отклонение признаков
X_train_scaled = scaler.fit_transform(X_train)

# масштабируем тестовую выборку используя статистики обучающей выборки
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Выбор подмножества признаков с помощью RFE

# %% [markdown]
# Если есть estimator, который позволяет раздать веса признакам (у нас уже была такая модель - линейной регрессии), то recursive feature elimination (RFE) рассматривает рекурсивно все меньше и меньше признаков, убирая наименее важные. В результате чего дойдет до желанного количества признаков.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

# отберём с помощью RFE 5 признаков
rfe = RFE(estimator=LogisticRegression(), n_features_to_select=5)
rfe = rfe.fit(X_train_scaled, y_train)
# выведем эти 5 признаков
print('Selected features: %s' % list(rfe.get_feature_names_out(cols)))
# Out:
# Selected features: ['Pclass', 'Sex', 'Mr_Mrs', 'Family_Size', 'Alone']

# %% [markdown]
# RFECV позволяет выбрать оптимальное количество признаков кросс-валидацией

# %%
from sklearn.feature_selection import RFECV

rfecv = RFECV(estimator=LogisticRegression(), step=1, cv=5, scoring='accuracy')
rfecv.fit(X_train_scaled, y_train)

selected_features = list(rfecv.get_feature_names_out(cols))

print("Optimal number of features: %d" % rfecv.n_features_)
print('Selected features: %s' % selected_features)

plt.figure(figsize=(10,6))
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features: 7
# Selected features: ['Pclass', 'Sex', 'Embarked', 'Mr_Mrs', 'Age_category', 'Family_Size', 'Alone']

# %%
X = df[selected_features]

plt.subplots(figsize=(8, 5))
sns.heatmap(X.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# ### Обучение первой модели

# %%
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score 
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve, auc, log_loss

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42) # уже с отобранными призаками

scaler = StandardScaler()  # воспользуемся стандартным трансформером

# масштабируем обучающую выборку и запоминаем среднее, стандартное отклонение признаков
X_train_scaled = scaler.fit_transform(X_train)

# масштабируем тестовую выборку используя статистики обучающей выборки
X_test_scaled = scaler.transform(X_test)

logreg = LogisticRegression()
logreg.fit(X_train_scaled, y_train)
y_pred = logreg.predict(X_test_scaled)
y_pred_proba = logreg.predict_proba(X_test)[:, 1]  # предсказываем вероятность по классам
[fpr, tpr, thr] = roc_curve(y_test, y_pred_proba)
print('Train/Test split results:')
print(logreg.__class__.__name__+" accuracy is %2.3f" % accuracy_score(y_test, y_pred))
print(logreg.__class__.__name__+" log_loss is %2.3f" % log_loss(y_test, y_pred_proba))
print(logreg.__class__.__name__+" auc is %2.3f" % auc(fpr, tpr))

idx = np.min(np.where(tpr > 0.95)) # индекс первого threshold с tpr > 0.95

plt.figure()
plt.plot(fpr, tpr, color='coral', label='ROC curve (area = %0.3f)' % auc(fpr, tpr))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot([0,fpr[idx]], [tpr[idx],tpr[idx]], 'k--', color='blue')
plt.plot([fpr[idx],fpr[idx]], [0,tpr[idx]], 'k--', color='blue')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - specificity)', fontsize=14)
plt.ylabel('True Positive Rate (recall)', fontsize=14)
plt.title('Receiver operating characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

print("Using a threshold of %.3f " % thr[idx] + "guarantees a sensitivity of %.3f " % tpr[idx] +  
      "and a specificity of %.3f" % (1-fpr[idx]) + 
      ", i.e. a false positive rate of %.2f%%." % (np.array(fpr[idx])*100))
# Out:
# Train/Test split results:
# LogisticRegression accuracy is 0.813
# LogisticRegression log_loss is 0.970
# LogisticRegression auc is 0.867
# Using a threshold of 0.021 guarantees a sensitivity of 0.955 and a specificity of 0.338, i.e. a false positive rate of 66.24%.

# %% [markdown]
# ### K-fold кросс-валидация с использованием cross_val_score()

# %% [markdown]
# Обучаем модель с кросс-валидацией

# %%
from sklearn.model_selection import cross_val_score

logreg = LogisticRegression()
scores_accuracy = cross_val_score(logreg, X_train_scaled, y_train, cv=5, scoring='accuracy')
scores_log_loss = cross_val_score(logreg, X_train_scaled, y_train, cv=5, scoring='neg_log_loss')
scores_auc = cross_val_score(logreg, X_train_scaled, y_train, cv=5, scoring='roc_auc')
print('K-fold cross-validation results:')
print(logreg.__class__.__name__+" average accuracy is %2.3f" % scores_accuracy.mean())
print(logreg.__class__.__name__+" average log_loss is %2.3f" % -scores_log_loss.mean())
print(logreg.__class__.__name__+" average auc is %2.3f" % scores_auc.mean())
# Out:
# K-fold cross-validation results:
# LogisticRegression average accuracy is 0.806
# LogisticRegression average log_loss is 0.456
# LogisticRegression average auc is 0.847

# %% [markdown]
# ### Подбор гиперпараметров с помощью GridSearchCV + multiple scorers

# %% [markdown]
# Обучаем модель с CV и ищем по сетке гиперпараметр C (чем меньше C тем больше регуляризация).

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': np.arange(1e-05, 5, 0.1)}
scoring = {'Accuracy': 'accuracy', 'AUC': 'roc_auc', 'Log_loss': 'neg_log_loss'}

gs = GridSearchCV(LogisticRegression(), return_train_score=True,
                  param_grid=param_grid, scoring=scoring, cv=5, refit='Accuracy')

gs.fit(X_train_scaled, y_train)
results = gs.cv_results_

print('='*20)
print("best estimator: " + str(gs.best_estimator_))
print("best params: " + str(gs.best_params_))
print('best score:', gs.best_score_)
print('='*20)

plt.figure(figsize=(13, 10))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously",fontsize=16)

plt.xlabel("Inverse of regularization strength: C")
plt.ylabel("Score")
plt.grid()

ax = plt.gca()
ax.set_xlim(0, param_grid['C'].max()) 
ax.set_ylim(0.35, 0.95)

X_axis = np.array(results['param_C'].data, dtype=float)

for scorer, color in zip(list(scoring.keys()), ['g', 'k', 'b']): 
    for sample, style in (('train', '--'), ('test', '-')):
        sample_score_mean = -results['mean_%s_%s' % (sample, scorer)] if scoring[scorer]=='neg_log_loss' else results['mean_%s_%s' % (sample, scorer)]
        sample_score_std = results['std_%s_%s' % (sample, scorer)]
        ax.fill_between(X_axis, sample_score_mean - sample_score_std,
                        sample_score_mean + sample_score_std,
                        alpha=0.1 if sample == 'test' else 0, color=color)
        ax.plot(X_axis, sample_score_mean, style, color=color,
                alpha=1 if sample == 'test' else 0.7,
                label="%s (%s)" % (scorer, sample))

    best_index = np.nonzero(results['rank_test_%s' % scorer] == 1)[0][0]
    best_score = -results['mean_test_%s' % scorer][best_index] if scoring[scorer]=='neg_log_loss' else results['mean_test_%s' % scorer][best_index]
        
    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.2f" % best_score,
                (X_axis[best_index], best_score + 0.005))

plt.legend(loc="best")
plt.grid('off')
plt.show()
# Out:
# ====================
# best estimator: LogisticRegression(C=0.20001000000000002)
# best params: {'C': 0.20001000000000002}
# best score: 0.8057548387096775
# ====================

# %% [markdown]
# ### GridSearchCV + multiple scorers + RepeatedStratifiedKFold + pipeline

# %% [markdown]
# Поиск по сетке с помощью CV, повторяющийся несколько раз, с масштабированием и различными scorers. StratifiedKFold позволяет разделять выборки с сохранением соотношения объектов каждого класса (стратифицированно).

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline

C = np.arange(1e-05, 5, 0.1)
scoring = {'Accuracy': 'accuracy', 'AUC': 'roc_auc', 'Log_loss': 'neg_log_loss'}
log_reg = LogisticRegression()

std_scale = StandardScaler()

n_folds=5
n_repeats=5

rskfold = RepeatedStratifiedKFold(n_splits=n_folds, n_repeats=n_repeats, random_state=42)

log_clf_pipe = Pipeline(steps=[('scale',std_scale), ('clf',log_reg)])

log_clf = GridSearchCV(estimator=log_clf_pipe, cv=rskfold,
              scoring=scoring, return_train_score=True,
              param_grid=dict(clf__C=C), refit='Accuracy')

log_clf.fit(X, y)
results = log_clf.cv_results_


print('='*80)
print("best estimator: " + str(log_clf.best_estimator_))
print("best params: " + str(log_clf.best_params_))
print('best score:', log_clf.best_score_)
print('='*80)
# Out:
# ================================================================================
# best estimator: Pipeline(steps=[('scale', StandardScaler()),
#                 ('clf', LogisticRegression(C=0.30001000000000005))])
# best params: {'clf__C': 0.30001000000000005}
# best score: 0.8053995354968301
# ================================================================================

# %% [markdown]
# Визуализация GridSearchCV

# %%
plt.figure(figsize=(13, 10))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously", fontsize=16)

plt.xlabel("Inverse of regularization strength: C")
plt.ylabel("Score")

ax = plt.gca()
ax.set_xlim(0, C.max()) 
ax.set_ylim(0.35, 0.95)

X_axis = np.array(results["param_clf__C"].data, dtype=float)

for scorer, color in zip(list(scoring.keys()), ['g', 'k', 'b']): 
    for sample, style in (('train', '--'), ('test', '-')):
        sample_score_mean = -results['mean_%s_%s' % (sample, scorer)] if scoring[scorer]=='neg_log_loss' else results['mean_%s_%s' % (sample, scorer)]
        sample_score_std = results['std_%s_%s' % (sample, scorer)]
        ax.fill_between(X_axis, sample_score_mean - sample_score_std,
                        sample_score_mean + sample_score_std,
                        alpha=0.1 if sample == 'test' else 0, color=color)
        ax.plot(X_axis, sample_score_mean, style, color=color,
                alpha=1 if sample == 'test' else 0.7,
                label="%s (%s)" % (scorer, sample))

    best_index = np.nonzero(results['rank_test_%s' % scorer] == 1)[0][0]
    best_score = -results['mean_test_%s' % scorer][best_index] if scoring[scorer]=='neg_log_loss' else results['mean_test_%s' % scorer][best_index]
        
    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.2f" % best_score,
                (X_axis[best_index], best_score + 0.005))

plt.legend(loc="best")
plt.grid(False)
plt.show()

# %%
print("Accuracy of Logistic Regression: {:.4f}".format(log_clf.best_score_))
# Out:
# Accuracy of Logistic Regression: 0.8054

# %% [markdown]
# ## <center>Часть 4. K-Nearest Neighbour (KNN)</center>

# %% [markdown]
# **KNN Algorithm**
# <br>
# <img src="http://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1531424125/KNN_final_a1mrv9.png"/>

# %%
from sklearn.neighbors import KNeighborsClassifier

n_neighbors = np.arange(1, 11, 2) # n_neighbors means k
#weights = ['uniform', 'distance'] # weight of each neighbor

scoring = {'Accuracy': 'accuracy', 'AUC': 'roc_auc', 'Log_loss': 'neg_log_loss'}

knn = KNeighborsClassifier()  

std_scale = StandardScaler()

n_folds=5
n_repeats=5

rskfold = RepeatedStratifiedKFold(n_splits=n_folds, n_repeats=n_repeats, random_state=12)

knn_clf_pipe = Pipeline(steps=[('scale',std_scale), ('clf',knn)])

knn_clf = GridSearchCV(estimator=knn_clf_pipe, cv=rskfold,
              scoring=scoring, return_train_score=True,
              param_grid=dict(clf__n_neighbors=n_neighbors), refit='Accuracy')

knn_clf.fit(X, y)
results = knn_clf.cv_results_


print('='*80)
print("best estimator: " + str(knn_clf.best_estimator_))
print("best params: " + str(knn_clf.best_params_))
print('best score:', knn_clf.best_score_)
print('='*80)
# Out:
# ================================================================================
# best estimator: Pipeline(steps=[('scale', StandardScaler()),
#                 ('clf', KNeighborsClassifier(n_neighbors=7))])
# best params: {'clf__n_neighbors': 7}
# best score: 0.8186102567321574
# ================================================================================

# %%
plt.figure(figsize=(13, 10))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously", fontsize=16)

plt.xlabel("Number of neighbors to use: n_neighbors")
plt.ylabel("Score")

ax = plt.gca()
ax.set_xlim(1, n_neighbors.max()) 
ax.set_ylim(0.0, 8.0)

X_axis = np.array(results["param_clf__n_neighbors"].data, dtype=int)

for scorer, color in zip(list(scoring.keys()), ['g', 'k', 'b']): 
    for sample, style in (('train', '--'), ('test', '-')):
        sample_score_mean = -results['mean_%s_%s' % (sample, scorer)] if scoring[scorer]=='neg_log_loss' else results['mean_%s_%s' % (sample, scorer)]
        sample_score_std = results['std_%s_%s' % (sample, scorer)]
        ax.fill_between(X_axis, sample_score_mean - sample_score_std,
                        sample_score_mean + sample_score_std,
                        alpha=0.1 if sample == 'test' else 0, color=color)
        ax.plot(X_axis, sample_score_mean, style, color=color,
                alpha=1 if sample == 'test' else 0.7,
                label="%s (%s)" % (scorer, sample))

    best_index = np.nonzero(results['rank_test_%s' % scorer] == 1)[0][0]
    best_score = -results['mean_test_%s' % scorer][best_index] if scoring[scorer]=='neg_log_loss' else results['mean_test_%s' % scorer][best_index]
        
    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.2f" % best_score,
                (X_axis[best_index], best_score + 0.005))

plt.legend(loc="best")
plt.grid(False)
plt.show()

# %%
print("Accuracy of KNN: {:.4f}".format(knn_clf.best_score_))
# Out:
# Accuracy of KNN: 0.8186

# %% [markdown]
# ## <center>Часть 5. Naive Bayes (NB)</center>

# %% [markdown]
# **Naive Bayes Algorithm**
# <br>
# <img src="https://s3.ap-south-1.amazonaws.com/techleer/204.png" width="500px"/>

# %%
from sklearn.naive_bayes import GaussianNB

var_smoothing = np.logspace(0, -9, num=100) # portion of the largest variance of all features that is added to variances for calculation stability

scoring = {'Accuracy': 'accuracy', 'AUC': 'roc_auc', 'Log_loss': 'neg_log_loss'}

nb = GaussianNB()  

std_scale = StandardScaler()

n_folds=5
n_repeats=5

rskfold = RepeatedStratifiedKFold(n_splits=n_folds, n_repeats=n_repeats, random_state=12)

nb_clf_pipe = Pipeline(steps=[('scale',std_scale), ('clf',nb)])

nb_clf = GridSearchCV(estimator=nb_clf_pipe, cv=rskfold,
              scoring=scoring, return_train_score=True,
              param_grid=dict(clf__var_smoothing=var_smoothing), refit='Accuracy')

nb_clf.fit(X, y)
results = nb_clf.cv_results_


print('='*80)
print("best estimator: " + str(nb_clf.best_estimator_))
print("best params: " + str(nb_clf.best_params_))
print('best score:', nb_clf.best_score_)
print('='*80)
# Out:
# ================================================================================
# best estimator: Pipeline(steps=[('scale', StandardScaler()),
#                 ('clf', GaussianNB(var_smoothing=0.1873817422860384))])
# best params: {'clf__var_smoothing': 0.1873817422860384}
# best score: 0.8123344422823425
# ================================================================================

# %%
plt.figure(figsize=(13, 10))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously", fontsize=16)

plt.xlabel("Calculation stability: var_smoothing")
plt.ylabel("Score")

ax = plt.gca()
ax.set_xlim(0, var_smoothing.max()) 
ax.set_ylim(0.4, 0.95)

X_axis = np.array(results["param_clf__var_smoothing"].data, dtype=float)

for scorer, color in zip(list(scoring.keys()), ['g', 'k', 'b']): 
    for sample, style in (('train', '--'), ('test', '-')):
        sample_score_mean = -results['mean_%s_%s' % (sample, scorer)] if scoring[scorer]=='neg_log_loss' else results['mean_%s_%s' % (sample, scorer)]
        sample_score_std = results['std_%s_%s' % (sample, scorer)]
        ax.fill_between(X_axis, sample_score_mean - sample_score_std,
                        sample_score_mean + sample_score_std,
                        alpha=0.1 if sample == 'test' else 0, color=color)
        ax.plot(X_axis, sample_score_mean, style, color=color,
                alpha=1 if sample == 'test' else 0.7,
                label="%s (%s)" % (scorer, sample))

    best_index = np.nonzero(results['rank_test_%s' % scorer] == 1)[0][0]
    best_score = -results['mean_test_%s' % scorer][best_index] if scoring[scorer]=='neg_log_loss' else results['mean_test_%s' % scorer][best_index]
        
    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.2f" % best_score,
                (X_axis[best_index], best_score + 0.005))

plt.legend(loc="best")
plt.grid(False)
plt.show()

# %%
print("Accuracy of Naive Bayes: {:.4f}".format(nb_clf.best_score_))
# Out:
# Accuracy of Naive Bayes: 0.8123

# %% [markdown]
# ## Выводы
# - Accuracy of Logistic Regression - **0.8054**
# - Accuracy of KNN - **0.8186**
# - Accuracy of Naive Bayes - **0.8123**
